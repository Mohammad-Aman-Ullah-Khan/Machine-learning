# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammad-Aman-Ullah-Khan/Machine-learning/blob/main/10_1_Pytorch_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torch.nn as nn
import numpy as np
import torchvision.transforms as transforms

# %%
# Create tensors.
x = torch.tensor(1., requires_grad=True)
w = torch.tensor(2., requires_grad=True)
b = torch.tensor(3., requires_grad=True)

# %%
# Build a computational graph.
y = w * x + b    # y = 2x + 3

# %%
# Compute gradients.
y.backward()

# Print out the gradients.
print(x.grad)    # x.grad = 2
print(w.grad)    # w.grad = 1
print(b.grad)    # b.grad = 1
# Out:
# tensor(2.)
# tensor(1.)
# tensor(1.)

# %% [markdown]
# 2. Basic autograd example

# %%
# Create tensors of shape (10, 3) and (10, 2).
x = torch.randn(10, 3)
y = torch.randn(10, 2)

# %%
# Build a fully connected layer.
linear = nn.Linear(3, 2)
print ('w: ', linear.weight)
print ('b: ', linear.bias)
# Out:
# w:  Parameter containing:
# tensor([[ 0.3824, -0.1487,  0.4169],
#         [-0.0103,  0.5161,  0.5036]], requires_grad=True)
# b:  Parameter containing:
# tensor([-0.4840, -0.5739], requires_grad=True)

# %%
# Build loss function and optimizer.
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(linear.parameters(), lr=0.01)

# %%
# Forward pass.
pred = linear(x)

# %%
pred.shape
# Out:
# torch.Size([10, 2])

# %%
# Compute loss.
loss = criterion(pred, y)
print('loss: ', loss.item())
# Out:
# loss:  1.948655366897583

# %%
# Backward pass.
loss.backward()

# %%
# Print out the gradients.
print ('dL/dw: ', linear.weight.grad)
print ('dL/db: ', linear.bias.grad)
# Out:
# dL/dw:  tensor([[0.8254, 0.2079, 0.3606],
#         [0.4140, 1.2851, 1.2497]])
# dL/db:  tensor([-0.3417, -0.2528])

# %%
# 1-step gradient descent.
optimizer.step()

# %%
# You can also perform gradient descent at the low level.
# linear.weight.data.sub_(0.01 * linear.weight.grad.data)
# linear.bias.data.sub_(0.01 * linear.bias.grad.data)

# Print out the loss after 1-step gradient descent.
pred = linear(x)
loss = criterion(pred, y)
print('loss after 1 step optimization: ', loss.item())
# Out:
# loss after 1 step optimization:  1.9048454761505127
